# %%
import pandas as pd
import json
import boto3

# data to sink
df = pd.read_csv('../data/dao-data.csv')

# aws configuration
rds_client = boto3.client('rds-data', region_name='us-west-2')
db_name = 'daoinfo'
db_cluster_arn = 'arn:aws:rds:us-west-2:287560958655:cluster:daohacks'
db_secret_arn = 'arn:aws:secretsmanager:us-west-2:287560958655:secret:rds-db-credentials/cluster-4XNQSEHC3REQFG6BXFUBGGRQGA/admin-fhI6AJ'

# %%
# helper function
def execute_statement(sql):
    res = rds_client.execute_statement(
        secretArn = db_secret_arn,
        database=db_name,
        resourceArn=db_cluster_arn,
        sql=sql
    )
    return res

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
host='daohacks.cluster-cm6ydja7lrk5.us-west-2.rds.amazonaws.com'
port=int(3306)
user='admin'
passw='NewEraAdmin123!'
database='daohacks'

# %%
mydb = create_engine('mysql+pymysql://' + user + ':' + passw + '@' + host + ':' + str(port) + '/' + database, echo=False)

# %%
df.to_sql(name='daoinfo', con=mydb, if_exists = 'replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/py3/lib/python3.8/site-packages/pymysql/connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~/anaconda3/envs/py3/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~/anaconda3/envs/py3/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
        [
          {
            "stringValue": "MetaversePRO"
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "isNull": true
          },
          {
            "stringValue": "The Reserve Currency for Metaverse and Blockchain"
          },
          {
            "stringValue": "https://daocentral.com/_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=3840&q=75"
          },
          {
            "stringValue": "/_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=640&q=75 640w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=750&q=75 750w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=828&q=75 828w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=1080&q=75 1080w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=1200&q=75 1200w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=1920&q=75 1920w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=2048&q=75 2048w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1643589169%2Fg3cobcywssvxy1v2wwpn.jpg&w=3840&q=75 3840w"
          },
          {
            "stringValue": "https://daocentral.com/_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=3840&q=75"
          },
          {
            "stringValue": "/_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=640&q=75 640w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=750&q=75 750w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=828&q=75 828w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=1080&q=75 1080w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=1200&q=75 1200w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=1920&q=75 1920w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=2048&q=75 2048w, /_next/image?url=http%3A%2F%2Fres.cloudinary.com%2Fdaojones%2Fimage%2Fupload%2Fv1640243952%2Fbjce5jw1bpzcmt6obfjt.png&w=3840&q=75 3840w"
          },
          {
            "stringValue": "['Protocol']"
          },
          {
            "stringValue": "https://twitter.com/MetaverseProDAO"
          },
          {
            "stringValue": "https://discord.com/invite/metaversepro"
          },
          {
            "isNull": true
          },
          {
            "stringValue": "https://metaverse.pro/"
          },
          {
            "stringValue": "0x0a2046C7fAa5a5F2b38C0599dEB4310AB781CC83"
          },
          {
            "stringValue": "https://bscxplorer.com/address//0x0a2046C7fAa5a5F2b38C0599dEB4310AB781CC83"
          },
          {
            "stringValue": "<h2>Our Mission</h2><p>MetaversePRO is a fair, community-governed, financial infrastructure for the Metaverse that allows for stable and dependable growth.</p><p>MetaversePRO has chosen to operate on Binance Smart Chain because we believe BSC represents the optimal intersection between the real world and the Metaverse. Plus, the Metaverse on BSC is currently experiencing phenomenal growth, from artworks, to GameFi, to DeFi. All areas are seeing an explosion of innovation. MetaversePRO is committed to building a fair token-issuing institution and to having META accepted across the Metaverse. Just as DeFi requires an infrastructure, MetaversePRO will serve this role for GameFi.</p><h2>Our Values</h2><ul><li>Sustainability</li><li>Create a real store of value</li></ul>"
          },
          {
            "stringValue": "['? -2.87% (-$0.097)', '$157.23', '$410.29', '$2.89', '$134,487', '$132,179.43', '40,992', '40,421.843']"
          }
        ],
